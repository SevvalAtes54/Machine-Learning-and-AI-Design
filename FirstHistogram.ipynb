# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.title("histogram")
plt.xlabel("values")
plt.ylabel("frequencyyy")

plt.show()
