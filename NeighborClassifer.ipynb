# %%
import numpy as np

# %%
import pandas as pd
from sklearn.datasets import load_diabetes

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

iris = load_diabetes()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)


knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)


y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Modelin Doğruluğu: {accuracy:.2f}")

,plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap='viridis', edgecolor='k')
plt.title('Diyabet Test Verisi')
plt.xlabel('Diabete age')
plt.ylabel('Diabete kilogram')
plt.show()
# Out:
# Modelin Doğruluğu: 0.01
